# %%
import gzip
import csv
import json
import pandas as pd

# %%
#reading 100o rows from data
data = pd.read_csv('flightlist.csv.gz', nrows=1000, compression='gzip',
                   error_bad_lines=False)
print(data)

# %%
#column list
list(data)
# Out:
# ['callsign',
#  'number',
#  'icao24',
#  'registration',
#  'typecode',
#  'origin',
#  'destination',
#  'firstseen',
#  'lastseen',
#  'day']

# %%
#to drop if any value in the row has a nan
df_clean = data.dropna(how='any')
df_clean
# Out:
#     callsign  number  icao24 registration typecode origin destination  \
# 13    CES516   MU516  7807d6       B-6538     A332   RJBB        RJBB
# 17    VOI938   Y4938  0d036e       XA-VOI     A319   KLAX        KPDX
# 19    CSN328   CZ328  780737       B-6137     A388   KLAX        YSSY
# 20    UAE358   EK358  8963db       A6-EPL     B77W   OMDB        OMDB
# 24      UAL9     UA9  a2a2e3       N26906     B788   KSFO        KSFO
# ..       ...     ...     ...          ...      ...    ...         ...
# 976  UAL2271  UA2271  a4dad4       N41140     B752   KLAS        KEWR
# 977   AAL612   AA612  a968f8       N705UW     A319   TBPB        KCLT
# 980   UAE194   EK194  896316       A6-ENT     B77W   LPAR        OMDB
# 981   DAL460   DL460  a9acb8       N722TW     B752   KJFK        UT13
# 982    JAL17    JL17  8621ea       JA620J     B763   CYVR        CYVR
#
#                      firstseen                   lastseen  \
# 13   2019-12-31 06:02:26+00:00  2020-01-01 03:08:39+00:00
# ...
